# %%
# imports

import os
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(columns=["Job Name", "Slurm Job ID", "Slurm Nodes", "Slurm Node Count", "Slurm NTASKS", "Slurm CPUs per Task", "Slurm Memory per Node", "Slurm Time Limit", "Slurm Partition", "Slurm Account", "INIT_MODE", "RADIUS", "INIT_DEPTH", "TOTAL_STEPS", "SAVE_EVERY", "TARGET_WIDTH", "TARGET_HEIGHT", "CHUNK_SIZE", "MPI_RANKS", "IO_MODE", "MPI_SYNC_MODE", "RANK_GRID_X", "RANK_GRID_Z", "OVERWRITE_OUTPUT", "SKIP_RENDERING", "SKIP_COMPILE", "FFMPEG_THREADS", "RENDER_CPUS", "REDUCED_HEIGHT", "HEIGHT_MIN", "Preparation (s)", "Compilation (s)", "Solving (s)", "Top view rendering (s)", "Slice full height rendering (s)", "Slice reduced height rendering (s)", "Top view video (s)", "Slice full height video (s)", "Combined video 1:1 (s)", "Combined video 16:9 (s)", "Total (s)"])

for file in os.listdir("/hpcwork/thes2181/mini_app/"):
    # check if file is a directory
    if os.path.isdir(os.path.join("/hpcwork/thes2181/mini_app/", file)):
        if "d2000.0" in file:
            info_file = os.path.join(os.path.join("/hpcwork/thes2181/mini_app/", file), "timing_and_parameters.txt")
            if os.path.isfile(info_file):
                # Looks something like this:
                """
Job Name: circle_r120_d2000.0_s1000000_2160x1080_c23mm_16n_96t_1c__rank0_gather_none
Slurm Job ID: 65324502
Slurm Nodes: n23m[0077,0147,0162-0163,0230-0231,0363-0364],r23m[0029,0035,0106,0115,0175,0185,0187,0190]
Slurm NTASKS: 96
Slurm CPUs per Task: 1
Slurm Memory per Node: N/A
Slurm Time Limit: N/A
Slurm Partition: c23mm
Slurm Account: N/A

Parameters:
INIT_MODE: circle
RADIUS: 120
INIT_DEPTH: 2000.0
TOTAL_STEPS: 1000000
SAVE_EVERY: 100
TARGET_WIDTH: 2160
TARGET_HEIGHT: 1080
CHUNK_SIZE: 60
MPI_RANKS: 96
IO_MODE: rank0_gather
MPI_SYNC_MODE: none
RANK_GRID_X: 0
RANK_GRID_Z: 0
OVERWRITE_OUTPUT: 1
SKIP_RENDERING: 0
SKIP_COMPILE: 0
FFMPEG_THREADS: 16
RENDER_CPUS: 96
REDUCED_HEIGHT: 135
HEIGHT_MIN: 40

Timings (seconds):
Preparation: 10
Compilation: 3
Solving: 2474
Top view rendering: 238
Slice full height rendering: 248
Slice reduced height rendering: 238
Top view video: 482
Slice full height video: 378
Combined video 1:1: 341
Combined video 16:9: 305
Total: 4717
                """
                
                # We want to extract all the information from the info_file and add it to the DataFrame df
                row_data = {}
                
                with open(info_file, 'r') as f:
                    for line in f:
                        line = line.strip()
                        if "Job Name:" in line:
                            #Job Name: circle_r120_d2000.0_s1000000_2160x1080_c23mm_16n_96t_1c__rank0_gather_none
                            # the _16n_ here indicates 16 nodes, we want to extract that and put it in the Slurm Node Count column
                            row_data["Slurm Node Count"] = re.search(r'_(\d+)n_', line).group(1)
                        if ':' in line and line and not line.startswith('Parameters') and not line.startswith('Timings'):
                            key, value = line.split(':', 1)
                            key = key.strip()
                            value = value.strip()
                            
                            # Map timing keys to column names with (s) suffix
                            if key in ["Preparation", "Compilation", "Solving", "Top view rendering", 
                                       "Slice full height rendering", "Slice reduced height rendering",
                                       "Top view video", "Slice full height video", "Combined video 1:1", 
                                       "Combined video 16:9", "Total"]:
                                col_name = f"{key} (s)"
                            else:
                                col_name = key
                            
                            row_data[col_name] = value
                
                # Add the row to the DataFrame
                df = pd.concat([df, pd.DataFrame([row_data])], ignore_index=True)
                
    # Print the DataFrame
print(df)
# Out:
#                                             Job Name Slurm Job ID  \
# 0  circle_r120_d2000.0_s1000000_2160x1080_c23mm_2...     65324477
# 1  circle_r120_d2000.0_s1000000_2160x1080_c23mm_1...     65324507
# 2  circle_r120_d2000.0_s1000000_2160x1080_c23mm_1...     65324502
# 3  circle_r120_d2000.0_s1000000_2160x1080_c23mm_2...     65324522
# 4  circle_r120_d2000.0_s1000000_2160x1080_c23mm_1...     65324461
# 5  circle_r120_d2000.0_s1000000_2160x1080_c23mm_8...     65324500
# 6  circle_r120_d2000.0_s1000000_2160x1080_c23mm_1...     65324570
# 7  circle_r120_d2000.0_s1000000_2160x1080_c23mm_4...     65324498
# 8  circle_r120_d2000.0_s1000000_2160x1080_c23mm_8...     65324569
#
#                                          Slurm Nodes Slurm Node Count  \
# 0                                    n23m[0217,0409]                2
# 1                                           n23m0364                1
# 2  n23m[0077,0147,0162-0163,0230-0231,0363-0364],...               16
# 3                                    n23m[0218,0409]                2
# 4                                           r23m0035                1
# 5  n23m[0150,0155,0222-0223,0234-0235],r23m[0037,...                8
# 6  n23m[0001-0002,0004-0005,0007-0008,0010,0017-0...               16
# 7                    n23m[0077,0081],r23m[0116,0185]                4
# 8  n23m[0150,0155,0222-0223,0234-0235],r23m[0037,...                8
#
#   Slurm NTASKS Slurm CPUs per Task Slurm Memory per Node Slurm Time Limit  \
# 0           96                   1                   N/A              N/A
# 1           96                   1                   N/A              N/A
# 2           96                   1                   N/A              N/A
# 3           96                   1                   N/A              N/A
# 4           96                   1                   N/A              N/A
# 5           96                   1                   N/A              N/A
# 6           96                   1                   N/A              N/A
# 7           96                   1                   N/A              N/A
# 8           96                   1                   N/A              N/A
#
#   Slurm Partition Slurm Account  ... Top view rendering (s)  \
# 0           c23mm           N/A  ...                    235
# 1           c23mm           N/A  ...                    194
# 2           c23mm           N/A  ...                    238
# 3           c23mm           N/A  ...                    278
# 4           c23mm           N/A  ...                    228
# 5           c23mm           N/A  ...                    251
# 6           c23mm           N/A  ...                    982
# 7           c23mm           N/A  ...                    228
# 8           c23mm           N/A  ...                    552
#
#   Slice full height rendering (s) Slice reduced height rendering (s)  \
# 0                             244                                254
# 1                             265                                260
# 2                             248                                238
# 3                             226                                233
# 4                             259                                264
# 5                             281                                253
# 6                             345                                341
# 7                             256                                248
# 8                             276                                267
#
#   Top view video (s) Slice full height video (s) Combined video 1:1 (s)  \
# 0                481                         377                    NaN
# 1                481                         376                    NaN
# 2                482                         378                    NaN
# 3                481                         377                    NaN
# 4                481                         375                    NaN
# 5                482                         378                    NaN
# 6                482                         377                    NaN
# 7                482                         378                    NaN
# 8                483                         378                    NaN
#
#   Combined video 16:9 (s) Total (s) Combined video 1 Combined video 16
# 0                     NaN      4959           1: 339            9: 298
# 1                     NaN      6499           1: 333            9: 295
# 2                     NaN      4717           1: 341            9: 305
# 3                     NaN      6321           1: 397            9: 305
# 4                     NaN      5643           1: 332            9: 295
# 5                     NaN      4798           1: 341            9: 305
# 6                     NaN      6906           1: 339            9: 305
# 7                     NaN      4766           1: 339            9: 300
# 8                     NaN      6323           1: 339            9: 306
#
# [9 rows x 43 columns]

# %%
# Let's plot the solving time on the y-axis and the amount of nodes on the x-axis
# Separate lines for each IO_MODE
plt.figure(figsize=(10, 6))

# Filter data for each IO_MODE
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()

# Convert to numeric for proper sorting and plotting
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Solving (s)"] = pd.to_numeric(rank0_gather["Solving (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Solving (s)"] = pd.to_numeric(parallel_hdf5["Solving (s)"], errors='coerce')

# Sort after converting to numeric
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")

# Plot lines
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Solving (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Solving (s)"], color='red', marker='s', label='parallel_hdf5')

plt.title("Solving Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Solving Time (s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Preparation time
plt.figure(figsize=(10, 6))
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Preparation (s)"] = pd.to_numeric(rank0_gather["Preparation (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Preparation (s)"] = pd.to_numeric(parallel_hdf5["Preparation (s)"], errors='coerce')
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Preparation (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Preparation (s)"], color='red', marker='s', label='parallel_hdf5')
plt.title("Preparation Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Preparation Time (s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Compilation time
plt.figure(figsize=(10, 6))
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Compilation (s)"] = pd.to_numeric(rank0_gather["Compilation (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Compilation (s)"] = pd.to_numeric(parallel_hdf5["Compilation (s)"], errors='coerce')
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Compilation (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Compilation (s)"], color='red', marker='s', label='parallel_hdf5')
plt.title("Compilation Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Compilation Time (s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Top view rendering time
plt.figure(figsize=(10, 6))
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Top view rendering (s)"] = pd.to_numeric(rank0_gather["Top view rendering (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Top view rendering (s)"] = pd.to_numeric(parallel_hdf5["Top view rendering (s)"], errors='coerce')
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Top view rendering (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Top view rendering (s)"], color='red', marker='s', label='parallel_hdf5')
plt.title("Top view Rendering Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Top view Rendering Time (s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Slice full height rendering time
plt.figure(figsize=(10, 6))
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Slice full height rendering (s)"] = pd.to_numeric(rank0_gather["Slice full height rendering (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Slice full height rendering (s)"] = pd.to_numeric(parallel_hdf5["Slice full height rendering (s)"], errors='coerce')
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Slice full height rendering (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Slice full height rendering (s)"], color='red', marker='s', label='parallel_hdf5')
plt.title("Slice Full Height Rendering Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Slice Full Height Rendering Time (s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Slice reduced height rendering time
plt.figure(figsize=(10, 6))
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Slice reduced height rendering (s)"] = pd.to_numeric(rank0_gather["Slice reduced height rendering (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Slice reduced height rendering (s)"] = pd.to_numeric(parallel_hdf5["Slice reduced height rendering (s)"], errors='coerce')
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Slice reduced height rendering (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Slice reduced height rendering (s)"], color='red', marker='s', label='parallel_hdf5')
plt.title("Slice Reduced Height Rendering Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Slice Reduced Height Rendering Time (s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Top view video time
plt.figure(figsize=(10, 6))
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Top view video (s)"] = pd.to_numeric(rank0_gather["Top view video (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Top view video (s)"] = pd.to_numeric(parallel_hdf5["Top view video (s)"], errors='coerce')
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Top view video (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Top view video (s)"], color='red', marker='s', label='parallel_hdf5')
plt.title("Top view Video Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Top view Video Time (s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Slice full height video time
plt.figure(figsize=(10, 6))
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Slice full height video (s)"] = pd.to_numeric(rank0_gather["Slice full height video (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Slice full height video (s)"] = pd.to_numeric(parallel_hdf5["Slice full height video (s)"], errors='coerce')
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Slice full height video (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Slice full height video (s)"], color='red', marker='s', label='parallel_hdf5')
plt.title("Slice Full Height Video Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Slice Full Height Video Time (s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Combined video 1:1 time
plt.figure(figsize=(10, 6))
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Combined video 1:1 (s)"] = pd.to_numeric(rank0_gather["Combined video 1:1 (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Combined video 1:1 (s)"] = pd.to_numeric(parallel_hdf5["Combined video 1:1 (s)"], errors='coerce')
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Combined video 1:1 (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Combined video 1:1 (s)"], color='red', marker='s', label='parallel_hdf5')
plt.title("Combined Video 1:1 Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Combined Video 1:1 Time (s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Combined video 16:9 time
plt.figure(figsize=(10, 6))
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Combined video 16:9 (s)"] = pd.to_numeric(rank0_gather["Combined video 16:9 (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Combined video 16:9 (s)"] = pd.to_numeric(parallel_hdf5["Combined video 16:9 (s)"], errors='coerce')
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Combined video 16:9 (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Combined video 16:9 (s)"], color='red', marker='s', label='parallel_hdf5')
plt.title("Combined Video 16:9 Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Combined Video 16:9 Time (s)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Total time
plt.figure(figsize=(10, 6))
rank0_gather = df[df["IO_MODE"] == "rank0_gather"].copy()
parallel_hdf5 = df[df["IO_MODE"] == "parallel_hdf5"].copy()
rank0_gather["Slurm Node Count"] = pd.to_numeric(rank0_gather["Slurm Node Count"], errors='coerce')
rank0_gather["Total (s)"] = pd.to_numeric(rank0_gather["Total (s)"], errors='coerce')
parallel_hdf5["Slurm Node Count"] = pd.to_numeric(parallel_hdf5["Slurm Node Count"], errors='coerce')
parallel_hdf5["Total (s)"] = pd.to_numeric(parallel_hdf5["Total (s)"], errors='coerce')
rank0_gather = rank0_gather.sort_values("Slurm Node Count")
parallel_hdf5 = parallel_hdf5.sort_values("Slurm Node Count")
plt.plot(rank0_gather["Slurm Node Count"], rank0_gather["Total (s)"], color='blue', marker='o', label='rank0_gather')
plt.plot(parallel_hdf5["Slurm Node Count"], parallel_hdf5["Total (s)"], color='red', marker='s', label='parallel_hdf5')
plt.title("Total Time vs. Number of Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Total Time (s)")
plt.legend()
plt.grid()
plt.show()
